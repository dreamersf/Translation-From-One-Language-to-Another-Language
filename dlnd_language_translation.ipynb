# %% [markdown]
# # 语言翻译
#
# 在此项目中，你将了解神经网络机器翻译这一领域。你将用由英语和法语语句组成的数据集，训练一个序列到序列模型（sequence to sequence model），该模型能够将新的英语句子翻译成法语。
#
# ## 获取数据
#
# 因为将整个英语语言内容翻译成法语需要大量训练时间，所以我们提供了一小部分的英语语料库。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## 探索数据
#
# 研究 view_sentence_range，查看并熟悉该数据的不同部分。

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## 实现预处理函数
#
# ### 文本到单词 id
#
# 和之前的 RNN 一样，你必须首先将文本转换为数字，这样计算机才能读懂。在函数 `text_to_ids()` 中，你需要将单词中的 `source_text` 和 `target_text` 转为 id。但是，你需要在 `target_text` 中每个句子的末尾，添加 `<EOS>` 单词 id。这样可以帮助神经网络预测句子应该在什么地方结束。
#
#
# 你可以通过以下代码获取  `<EOS> ` 单词ID：
#
# ```python
# target_vocab_to_int['<EOS>']
# ```
#
# 你可以使用 `source_vocab_to_int` 和 `target_vocab_to_int` 获得其他单词 id。

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
   
    # TODO: Implement Function
    source_sentences = source_text.split('\n')
    source_id_text = [[source_vocab_to_int[word] for word in sentence.split()] for sentence in source_sentences ]
    
    target_sentences = target_text.split('\n')
    target_id_text = [[target_vocab_to_int[word] for word in sentence.split()] for sentence in target_sentences ]
#     print(target_id_text)
    for ll in target_id_text:
        ll.append(target_vocab_to_int['<EOS>'])
#     print(target_id_text)
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %%
debug = 0

# %%
def debugprint(farg, *args):
    if debug != 0:
        print(farg)
        for arg in args:
            print(arg)
    else:
        pass

# %% [markdown]
# ### 预处理所有数据并保存
#
# 运行以下代码单元，预处理所有数据，并保存到文件中。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，可以从这里继续。预处理的数据已保存到磁盘上。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### 检查 TensorFlow 版本，确认可访问 GPU
#
# 这一检查步骤，可以确保你使用的是正确版本的 TensorFlow，并且能够访问 GPU。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## 构建神经网络
#
# 你将通过实现以下函数，构建出要构建一个序列到序列模型所需的组件：
#
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### 输入
#
# 实现 `model_inputs()` 函数，为神经网络创建 TF 占位符。该函数应该创建以下占位符：
#
# - 名为 “input” 的输入文本占位符，并使用 TF Placeholder 名称参数（等级（Rank）为 2）。
# - 目标占位符（等级为 2）。
# - 学习速率占位符（等级为 0）。
# - 名为 “keep_prob” 的保留率占位符，并使用 TF Placeholder 名称参数（等级为 0）。
#
# 在以下元祖（tuple）中返回占位符：（输入、目标、学习速率、保留率）

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32,shape=[None,None],name='input')
    targets = tf.placeholder(tf.int32,[None,None],name='targets')
    learning_rate = tf.placeholder(tf.float32,name='leanring_rate')
    keep_probability = tf.placeholder(tf.float32,name='keep_prob')
    return (inputs, targets, learning_rate, keep_probability)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 处理解码输入
#
# 使用 TensorFlow 实现 `process_decoding_input`，以便删掉 `target_data` 中每个批次的最后一个单词 ID，并将 GO ID 放到每个批次的开头。

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    '''
    print('target_data',target_data,'\nbatch_size',batch_size)
    a = [int(target_data.get_shape()[0]),int(target_data.get_shape()[1]-1)]
    print('a',a)
    zero_left = tf.constant(target_vocab_to_int['<GO>'],shape=[batch_size,1])
    aa = tf.slice(target_data,[0,1],[int(target_data.get_shape()[0]),int(target_data.get_shape()[1]-1)])
    print('aa',aa)
    aaa = tf.concat([zero_left,aa],1)
    print(aaa)
    '''
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
#     print('ending',ending)
    start = tf.constant(target_vocab_to_int['<GO>'],shape=[batch_size,1])
#     start =tf.fill([batch_size, 1], target_vocab_to_int['<GO>'],dtype=tf.float32)
#     print('start',start,'ending',ending)
    dec_input = tf.concat([start, ending], 1)
    
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### 编码
#
# 实现 `encoding_layer()`，以使用 [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn) 创建编码器 RNN 层级。

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
#     embedding = tf.Variable(tf.random_uniform([n_words,embed_size],-1,1))
#     print('embedding',embedding)
#     embeded = tf.nn.embedding_lookup(embedding,rnn_inputs)
#     print('embeded',embeded)
#     vob_size = int(rnn_inputs.get_shape()[2])
#     seq_length = int(rnn_inputs.get_shape()[1])
#     batch_size = int(rnn_inputs.get_shape()[0])
    '''
    rnn_cell = tf.nn.rnn_cell.BasicRNNCell(rnn_size)
    '''
#     enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs,vob_size,rnn_size)
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    
    cell = tf.contrib.rnn.MultiRNNCell([lstm]*num_layers)
    
    drop = tf.contrib.rnn.DropoutWrapper(cell,output_keep_prob=keep_prob)
#     outputs, final_state = tf.nn.dynamic_r nn(cell,embed,initial_state=initial_state)
    '''
    print('rnn_inputs', rnn_inputs, '\nrnn_size', rnn_size, '\nnum_layers', num_layers, '\nkeep_prob',keep_prob)
    print('cell',cell,'\nrnn_inputs',rnn_inputs,'\ninitial_state',initial_state)
    '''
#     source_sequence_length = tf.placeholder(tf.int32)
    outputs, final_state = tf.nn.dynamic_rnn(drop,rnn_inputs,dtype=tf.float32)
#     final_state = tf.identity(final_state,name='final_state')
    return final_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 训练
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建训练分对数（training logits）。将 `output_fn` 应用到 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 输出上。

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
#     '''
#     print('encoder_state', encoder_state, '\ndec_cell',dec_cell, '\ndec_embed_input', dec_embed_input, '\nsequence_length', sequence_length, '\ndecoding_scope',decoding_scope,
#                          '\noutput_fn', output_fn, '\nkeep_prob', keep_prob)
#     '''
    '''
    The `simple_decoder_fn_train` is a simple training function for a
  sequence-to-sequence model. It should be used when `dynamic_rnn_decoder` is
  in the training mode.

    '''
    dynamic_fn_train = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    
    outputs, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(
        dec_cell, dynamic_fn_train, dec_embed_input, sequence_length, scope=decoding_scope)
    # Apply output function
    train_logits = tf.nn.dropout(outputs, keep_prob)
    train_logits =  output_fn(train_logits)
    # dropout层
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 推论
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建推论分对数（inference logits）。

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    debugprint('encoder_state',encoder_state, '\ndec_cell',dec_cell, '\ndec_embeddings', dec_embeddings, '\nstart_of_sequence_id', start_of_sequence_id, '\nend_of_sequence_id', end_of_sequence_id,
                         '\nmaximum_length', maximum_length, '\nvocab_size', vocab_size, '\ndecoding_scope', decoding_scope, '\noutput_fn', output_fn, '\nkeep_prob',keep_prob)
    dynamic_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, 
        maximum_length, vocab_size)
    outputs, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, dynamic_decoder_fn, scope=decoding_scope)
#     inference_logits = tf.nn.dropout(outputs, keep_prob)
    return outputs


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建解码层级
#
# 实现 `decoding_layer()` 以创建解码器 RNN 层级。
#
# - 使用 `rnn_size` 和 `num_layers` 创建解码 RNN 单元。
# - 使用 [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) 创建输出函数，将输入，也就是分对数转换为类分对数（class logits）。
# - 使用 `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` 函数获取训练分对数。
# - 使用 `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` 函数获取推论分对数。
#
# 注意：你将需要使用 [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 在训练和推论分对数间分享变量。

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    # 多层lstm
    dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)

    with tf.variable_scope("decoding") as decoding_scope:
        # Output Layer
        # 添加全连接层
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        # 解码-训练
        train_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob)    
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        # 解码-推理    
        infer_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'],
                         sequence_length, vocab_size, decoding_scope, output_fn, keep_prob)
    return train_logits, infer_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建神经网络
#
# 应用你在上方实现的函数，以：
#
# - 向编码器的输入数据应用嵌入。
# - 使用 `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)` 编码输入。
# - 使用 `process_decoding_input(target_data, target_vocab_to_int, batch_size)` 函数处理目标数据。
# - 向解码器的目标数据应用嵌入。
# - 使用 `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)` 解码编码的输入数据。

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    debugprint(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int)
    embedding = tf.Variable(tf.random_uniform([source_vocab_size,enc_embedding_size],-1,1))
    embeded = tf.nn.embedding_lookup(embedding,input_data)
    debugprint('embeded',embeded)
    encoding_state = encoding_layer(embeded,rnn_size,num_layers,keep_prob)
    target_data = process_decoding_input(target_data,target_vocab_to_int,batch_size)
    embedding_decode = tf.Variable(tf.random_uniform([target_vocab_size,dec_embedding_size],-1,1))
    embeded_decode = tf.nn.embedding_lookup(embedding_decode,target_data)
    debugprint('embeded_decode',embeded_decode,'\nbatch_size',batch_size)
#     dec_embed_input, dec_embedding = embed...
    train_logits, infer_logits = decoding_layer(embeded_decode,embedding_decode,encoding_state,target_vocab_size,sequence_length,rnn_size,
                   num_layers,target_vocab_to_int,keep_prob)
    debugprint('train_logits', train_logits, '\ninfer_logits', infer_logits)
    return train_logits, infer_logits
#     return None,None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络
#
# ### 超参数
#
# 调试以下参数：
#
# - 将 `epochs` 设为 epoch 次数。
# - 将 `batch_size` 设为批次大小。
# - 将 `rnn_size` 设为 RNN 的大小。
# - 将 `num_layers` 设为层级数量。
# - 将 `encoding_embedding_size` 设为编码器嵌入大小。
# - 将 `decoding_embedding_size` 设为解码器嵌入大小
# - 将 `learning_rate` 设为训练速率。
# - 将 `keep_probability` 设为丢弃保留率（Dropout keep probability）。

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 1024
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 200
decoding_embedding_size = 200
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.6

# %% [markdown]
# ### 构建图表
#
# 使用你实现的神经网络构建图表。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### 训练
#
# 利用预处理的数据训练神经网络。如果很难获得低损失值，请访问我们的论坛，看看其他人是否遇到了相同的问题。

# %%
print('save_path',save_path)
# Out:
# save_path checkpoints/dev

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            debugprint('xxx')
            debugprint('cost', cost,'\nsource_batch', source_batch,'\ntarget_batch', target_batch,'target_batch.shape[1]',
                  target_batch.shape[1],'keep_probability',keep_probability)
            debugprint('train_op',train_op,'input_data',input_data,
                  'targets',targets,'lr',lr,'sequence_length',sequence_length,'keep_prob',keep_prob)
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            debugprint('xxxxx')
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    print('save_path',save_path)
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/134 - Train Accuracy:  0.244, Validation Accuracy:  0.286, Loss:  5.880
# Epoch   0 Batch    1/134 - Train Accuracy:  0.277, Validation Accuracy:  0.345, Loss:  5.712
# Epoch   0 Batch    2/134 - Train Accuracy:  0.311, Validation Accuracy:  0.344, Loss:  5.422
# Epoch   0 Batch    3/134 - Train Accuracy:  0.311, Validation Accuracy:  0.344, Loss:  4.968
# Epoch   0 Batch    4/134 - Train Accuracy:  0.304, Validation Accuracy:  0.344, Loss:  4.408
# Epoch   0 Batch    5/134 - Train Accuracy:  0.310, Validation Accuracy:  0.342, Loss:  4.059
# Epoch   0 Batch    6/134 - Train Accuracy:  0.341, Validation Accuracy:  0.343, Loss:  3.690
# Epoch   0 Batch    7/134 - Train Accuracy:  0.322, Validation Accuracy:  0.361, Loss:  3.676
# Epoch   0 Batch    8/134 - Train Accuracy:  0.329, Validation Accuracy:  0.367, Loss:  3.572
# Epoch   0 Batch    9/134 - Train Accuracy:  0.361, Validation Accuracy:  0.362, Loss:  3.233
# Epoch   0 Batch   10/134 - Train Accuracy:  0.337, Validation Accuracy:  0.366, Loss:  3.257
# Epoch   0 Batch   11/134 - Train Accuracy:  0.356, Validation Accuracy:  0.383, Loss:  3.159
# Epoch   0 Batch   12/134 - Train Accuracy:  0.395, Validation Accuracy:  0.396, Loss:  2.936
# Epoch   0 Batch   13/134 - Train Accuracy:  0.359, Validation Accuracy:  0.398, Loss:  3.072
# Epoch   0 Batch   14/134 - Train Accuracy:  0.362, Validation Accuracy:  0.397, Loss:  2.974
# Epoch   0 Batch   15/134 - Train Accuracy:  0.371, Validation Accuracy:  0.405, Loss:  2.935
# Epoch   0 Batch   16/134 - Train Accuracy:  0.392, Validation Accuracy:  0.420, Loss:  2.839
# Epoch   0 Batch   17/134 - Train Accuracy:  0.392, Validation Accuracy:  0.421, Loss:  2.812
# Epoch   0 Batch   18/134 - Train Accuracy:  0.386, Validation Accuracy:  0.419, Loss:  2.780
# Epoch   0 Batch   19/134 - Train Accuracy:  0.390, Validation Accuracy:  0.424, Loss:  2.735
# Epoch   0 Batch   20/134 - Train Accuracy:  0.433, Validation Accuracy:  0.439, Loss:  2.579
# Epoch   0 Batch   21/134 - Train Accuracy:  0.419, Validation Accuracy:  0.443, Loss:  2.633
# Epoch   0 Batch   22/134 - Train Accuracy:  0.366, Validation Accuracy:  0.428, Loss:  2.758
# Epoch   0 Batch   23/134 - Train Accuracy:  0.418, Validation Accuracy:  0.421, Loss:  2.446
# Epoch   0 Batch   24/134 - Train Accuracy:  0.383, Validation Accuracy:  0.437, Loss:  2.659
# Epoch   0 Batch   25/134 - Train Accuracy:  0.411, Validation Accuracy:  0.448, Loss:  2.528
# Epoch   0 Batch   26/134 - Train Accuracy:  0.375, Validation Accuracy:  0.431, Loss:  2.604
# Epoch   0 Batch   27/134 - Train Accuracy:  0.405, Validation Accuracy:  0.433, Loss:  2.454
# Epoch   0 Batch   28/134 - Train Accuracy:  0.426, Validation Accuracy:  0.450, Loss:  2.427
# Epoch   0 Batch   29/134 - Train Accuracy:  0.437, Validation Accuracy:  0.446, Loss:  2.298
# Epoch   0 Batch   30/134 - Train Accuracy:  0.428, Validation Accuracy:  0.430, Loss:  2.270
# Epoch   0 Batch   31/134 - Train Accuracy:  0.407, Validation Accuracy:  0.436, Loss:  2.343
# Epoch   0 Batch   32/134 - Train Accuracy:  0.443, Validation Accuracy:  0.447, Loss:  2.215
# Epoch   0 Batch   33/134 - Train Accuracy:  0.407, Validation Accuracy:  0.443, Loss:  2.303
# Epoch   0 Batch   34/134 - Train Accuracy:  0.395, Validation Accuracy:  0.423, Loss:  2.261
# Epoch   0 Batch   35/134 - Train Accuracy:  0.420, Validation Accuracy:  0.425, Loss:  2.156
# Epoch   0 Batch   36/134 - Train Accuracy:  0.407, Validation Accuracy:  0.429, Loss:  2.191
# Epoch   0 Batch   37/134 - Train Accuracy:  0.389, Validation Accuracy:  0.428, Loss:  2.206
# Epoch   0 Batch   38/134 - Train Accuracy:  0.397, Validation Accuracy:  0.427, Loss:  2.162
# Epoch   0 Batch   39/134 - Train Accuracy:  0.402, Validation Accuracy:  0.429, Loss:  2.127
# Epoch   0 Batch   40/134 - Train Accuracy:  0.408, Validation Accuracy:  0.429, Loss:  2.097
# Epoch   0 Batch   41/134 - Train Accuracy:  0.399, Validation Accuracy:  0.431, Loss:  2.083
# Epoch   0 Batch   42/134 - Train Accuracy:  0.401, Validation Accuracy:  0.436, Loss:  2.082
# Epoch   0 Batch   43/134 - Train Accuracy:  0.407, Validation Accuracy:  0.436, Loss:  2.058
# Epoch   0 Batch   44/134 - Train Accuracy:  0.400, Validation Accuracy:  0.434, Loss:  2.032
# Epoch   0 Batch   45/134 - Train Accuracy:  0.410, Validation Accuracy:  0.439, Loss:  2.003
# Epoch   0 Batch   46/134 - Train Accuracy:  0.429, Validation Accuracy:  0.438, Loss:  1.905
# Epoch   0 Batch   47/134 - Train Accuracy:  0.399, Validation Accuracy:  0.435, Loss:  1.963
# Epoch   0 Batch   48/134 - Train Accuracy:  0.427, Validation Accuracy:  0.454, Loss:  1.935
# Epoch   0 Batch   49/134 - Train Accuracy:  0.426, Validation Accuracy:  0.448, Loss:  1.907
# Epoch   0 Batch   50/134 - Train Accuracy:  0.418, Validation Accuracy:  0.447, Loss:  1.901
# Epoch   0 Batch   51/134 - Train Accuracy:  0.425, Validation Accuracy:  0.458, Loss:  1.881
# Epoch   0 Batch   52/134 - Train Accuracy:  0.407, Validation Accuracy:  0.449, Loss:  1.882
# Epoch   0 Batch   53/134 - Train Accuracy:  0.417, Validation Accuracy:  0.457, Loss:  1.851
# Epoch   0 Batch   54/134 - Train Accuracy:  0.404, Validation Accuracy:  0.443, Loss:  1.839
# Epoch   0 Batch   55/134 - Train Accuracy:  0.393, Validation Accuracy:  0.434, Loss:  1.824
# Epoch   0 Batch   56/134 - Train Accuracy:  0.441, Validation Accuracy:  0.450, Loss:  1.726
# Epoch   0 Batch   57/134 - Train Accuracy:  0.407, Validation Accuracy:  0.443, Loss:  1.774
# Epoch   0 Batch   58/134 - Train Accuracy:  0.420, Validation Accuracy:  0.449, Loss:  1.740
# Epoch   0 Batch   59/134 - Train Accuracy:  0.402, Validation Accuracy:  0.455, Loss:  1.823
# Epoch   0 Batch   60/134 - Train Accuracy:  0.402, Validation Accuracy:  0.434, Loss:  1.722
# Epoch   0 Batch   61/134 - Train Accuracy:  0.404, Validation Accuracy:  0.441, Loss:  1.708
# Epoch   0 Batch   62/134 - Train Accuracy:  0.402, Validation Accuracy:  0.443, Loss:  1.678
# Epoch   0 Batch   63/134 - Train Accuracy:  0.397, Validation Accuracy:  0.426, Loss:  1.680
# Epoch   0 Batch   64/134 - Train Accuracy:  0.409, Validation Accuracy:  0.446, Loss:  1.685
# Epoch   0 Batch   65/134 - Train Accuracy:  0.400, Validation Accuracy:  0.435, Loss:  1.651
# Epoch   0 Batch   66/134 - Train Accuracy:  0.413, Validation Accuracy:  0.448, Loss:  1.624
# Epoch   0 Batch   67/134 - Train Accuracy:  0.382, Validation Accuracy:  0.455, Loss:  1.726
# Epoch   0 Batch   68/134 - Train Accuracy:  0.376, Validation Accuracy:  0.439, Loss:  1.679
# Epoch   0 Batch   69/134 - Train Accuracy:  0.421, Validation Accuracy:  0.455, Loss:  1.580
# Epoch   0 Batch   70/134 - Train Accuracy:  0.424, Validation Accuracy:  0.448, Loss:  1.552
# Epoch   0 Batch   71/134 - Train Accuracy:  0.398, Validation Accuracy:  0.435, Loss:  1.553
# Epoch   0 Batch   72/134 - Train Accuracy:  0.416, Validation Accuracy:  0.447, Loss:  1.548
# Epoch   0 Batch   73/134 - Train Accuracy:  0.424, Validation Accuracy:  0.434, Loss:  1.491
# Epoch   0 Batch   74/134 - Train Accuracy:  0.412, Validation Accuracy:  0.439, Loss:  1.528
# Epoch   0 Batch   75/134 - Train Accuracy:  0.444, Validation Accuracy:  0.447, Loss:  1.449
# Epoch   0 Batch   76/134 - Train Accuracy:  0.400, Validation Accuracy:  0.436, Loss:  1.489
# Epoch   0 Batch   77/134 - Train Accuracy:  0.455, Validation Accuracy:  0.448, Loss:  1.397
# Epoch   0 Batch   78/134 - Train Accuracy:  0.420, Validation Accuracy:  0.445, Loss:  1.468
# Epoch   0 Batch   79/134 - Train Accuracy:  0.428, Validation Accuracy:  0.452, Loss:  1.468
# Epoch   0 Batch   80/134 - Train Accuracy:  0.416, Validation Accuracy:  0.451, Loss:  1.453
# Epoch   0 Batch   81/134 - Train Accuracy:  0.424, Validation Accuracy:  0.454, Loss:  1.431
# Epoch   0 Batch   82/134 - Train Accuracy:  0.471, Validation Accuracy:  0.468, Loss:  1.344
# Epoch   0 Batch   83/134 - Train Accuracy:  0.417, Validation Accuracy:  0.450, Loss:  1.420
# Epoch   0 Batch   84/134 - Train Accuracy:  0.411, Validation Accuracy:  0.450, Loss:  1.400
# Epoch   0 Batch   85/134 - Train Accuracy:  0.438, Validation Accuracy:  0.466, Loss:  1.385
# Epoch   0 Batch   86/134 - Train Accuracy:  0.421, Validation Accuracy:  0.452, Loss:  1.388
# Epoch   0 Batch   87/134 - Train Accuracy:  0.434, Validation Accuracy:  0.462, Loss:  1.375
# Epoch   0 Batch   88/134 - Train Accuracy:  0.467, Validation Accuracy:  0.467, Loss:  1.293
# Epoch   0 Batch   89/134 - Train Accuracy:  0.431, Validation Accuracy:  0.464, Loss:  1.339
# Epoch   0 Batch   90/134 - Train Accuracy:  0.448, Validation Accuracy:  0.474, Loss:  1.340
# Epoch   0 Batch   91/134 - Train Accuracy:  0.498, Validation Accuracy:  0.462, Loss:  1.151
# Epoch   0 Batch   92/134 - Train Accuracy:  0.435, Validation Accuracy:  0.459, Loss:  1.296
# Epoch   0 Batch   93/134 - Train Accuracy:  0.453, Validation Accuracy:  0.469, Loss:  1.275
# Epoch   0 Batch   94/134 - Train Accuracy:  0.432, Validation Accuracy:  0.456, Loss:  1.277
# Epoch   0 Batch   95/134 - Train Accuracy:  0.457, Validation Accuracy:  0.483, Loss:  1.285
# Epoch   0 Batch   96/134 - Train Accuracy:  0.435, Validation Accuracy:  0.466, Loss:  1.273
# Epoch   0 Batch   97/134 - Train Accuracy:  0.434, Validation Accuracy:  0.469, Loss:  1.267
# Epoch   0 Batch   98/134 - Train Accuracy:  0.409, Validation Accuracy:  0.476, Loss:  1.308
# Epoch   0 Batch   99/134 - Train Accuracy:  0.436, Validation Accuracy:  0.471, Loss:  1.239
# Epoch   0 Batch  100/134 - Train Accuracy:  0.446, Validation Accuracy:  0.479, Loss:  1.235
# Epoch   0 Batch  101/134 - Train Accuracy:  0.433, Validation Accuracy:  0.493, Loss:  1.269
# Epoch   0 Batch  102/134 - Train Accuracy:  0.448, Validation Accuracy:  0.484, Loss:  1.211
# Epoch   0 Batch  103/134 - Train Accuracy:  0.476, Validation Accuracy:  0.479, Loss:  1.154
# Epoch   0 Batch  104/134 - Train Accuracy:  0.435, Validation Accuracy:  0.467, Loss:  1.171
# Epoch   0 Batch  105/134 - Train Accuracy:  0.464, Validation Accuracy:  0.487, Loss:  1.166
# Epoch   0 Batch  106/134 - Train Accuracy:  0.465, Validation Accuracy:  0.488, Loss:  1.159
# Epoch   0 Batch  107/134 - Train Accuracy:  0.495, Validation Accuracy:  0.501, Loss:  1.109
# Epoch   0 Batch  108/134 - Train Accuracy:  0.430, Validation Accuracy:  0.488, Loss:  1.201
# Epoch   0 Batch  109/134 - Train Accuracy:  0.489, Validation Accuracy:  0.501, Loss:  1.084
# Epoch   0 Batch  110/134 - Train Accuracy:  0.483, Validation Accuracy:  0.499, Loss:  1.104
# Epoch   0 Batch  111/134 - Train Accuracy:  0.485, Validation Accuracy:  0.504, Loss:  1.107
# Epoch   0 Batch  112/134 - Train Accuracy:  0.481, Validation Accuracy:  0.510, Loss:  1.106
# Epoch   0 Batch  113/134 - Train Accuracy:  0.543, Validation Accuracy:  0.502, Loss:  0.967
# Epoch   0 Batch  114/134 - Train Accuracy:  0.505, Validation Accuracy:  0.535, Loss:  1.093
# Epoch   0 Batch  115/134 - Train Accuracy:  0.407, Validation Accuracy:  0.470, Loss:  1.146
# Epoch   0 Batch  116/134 - Train Accuracy:  0.543, Validation Accuracy:  0.564, Loss:  1.101
# Epoch   0 Batch  117/134 - Train Accuracy:  0.464, Validation Accuracy:  0.498, Loss:  1.090
# Epoch   0 Batch  118/134 - Train Accuracy:  0.447, Validation Accuracy:  0.472, Loss:  1.055
# Epoch   0 Batch  119/134 - Train Accuracy:  0.566, Validation Accuracy:  0.546, Loss:  0.973
# Epoch   0 Batch  120/134 - Train Accuracy:  0.528, Validation Accuracy:  0.553, Loss:  1.052
# Epoch   0 Batch  121/134 - Train Accuracy:  0.461, Validation Accuracy:  0.493, Loss:  1.023
# Epoch   0 Batch  122/134 - Train Accuracy:  0.466, Validation Accuracy:  0.495, Loss:  1.038
# Epoch   0 Batch  123/134 - Train Accuracy:  0.531, Validation Accuracy:  0.546, Loss:  1.022
# Epoch   0 Batch  124/134 - Train Accuracy:  0.546, Validation Accuracy:  0.541, Loss:  0.964
# Epoch   0 Batch  125/134 - Train Accuracy:  0.538, Validation Accuracy:  0.562, Loss:  1.011
# Epoch   0 Batch  126/134 - Train Accuracy:  0.488, Validation Accuracy:  0.517, Loss:  0.996
# Epoch   0 Batch  127/134 - Train Accuracy:  0.520, Validation Accuracy:  0.532, Loss:  0.960
# Epoch   0 Batch  128/134 - Train Accuracy:  0.531, Validation Accuracy:  0.566, Loss:  1.000
# Epoch   0 Batch  129/134 - Train Accuracy:  0.543, Validation Accuracy:  0.565, Loss:  0.978
# Epoch   0 Batch  130/134 - Train Accuracy:  0.524, Validation Accuracy:  0.557, Loss:  0.982
# Epoch   0 Batch  131/134 - Train Accuracy:  0.516, Validation Accuracy:  0.555, Loss:  1.006
# Epoch   0 Batch  132/134 - Train Accuracy:  0.558, Validation Accuracy:  0.574, Loss:  0.945
# Epoch   1 Batch    0/134 - Train Accuracy:  0.550, Validation Accuracy:  0.577, Loss:  0.946
# Epoch   1 Batch    1/134 - Train Accuracy:  0.536, Validation Accuracy:  0.581, Loss:  0.978
# Epoch   1 Batch    2/134 - Train Accuracy:  0.566, Validation Accuracy:  0.579, Loss:  0.916
# Epoch   1 Batch    3/134 - Train Accuracy:  0.568, Validation Accuracy:  0.577, Loss:  0.919
# Epoch   1 Batch    4/134 - Train Accuracy:  0.573, Validation Accuracy:  0.586, Loss:  0.912
# Epoch   1 Batch    5/134 - Train Accuracy:  0.565, Validation Accuracy:  0.588, Loss:  0.919
# Epoch   1 Batch    6/134 - Train Accuracy:  0.598, Validation Accuracy:  0.594, Loss:  0.858
# Epoch   1 Batch    7/134 - Train Accuracy:  0.577, Validation Accuracy:  0.596, Loss:  0.894
# Epoch   1 Batch    8/134 - Train Accuracy:  0.580, Validation Accuracy:  0.595, Loss:  0.877
# Epoch   1 Batch    9/134 - Train Accuracy:  0.609, Validation Accuracy:  0.594, Loss:  0.835
# Epoch   1 Batch   10/134 - Train Accuracy:  0.580, Validation Accuracy:  0.594, Loss:  0.881
# Epoch   1 Batch   11/134 - Train Accuracy:  0.587, Validation Accuracy:  0.607, Loss:  0.883
# Epoch   1 Batch   12/134 - Train Accuracy:  0.621, Validation Accuracy:  0.613, Loss:  0.829
# Epoch   1 Batch   13/134 - Train Accuracy:  0.590, Validation Accuracy:  0.616, Loss:  0.877
# Epoch   1 Batch   14/134 - Train Accuracy:  0.596, Validation Accuracy:  0.613, Loss:  0.844
# Epoch   1 Batch   15/134 - Train Accuracy:  0.607, Validation Accuracy:  0.620, Loss:  0.846
# Epoch   1 Batch   16/134 - Train Accuracy:  0.605, Validation Accuracy:  0.617, Loss:  0.831
# Epoch   1 Batch   17/134 - Train Accuracy:  0.604, Validation Accuracy:  0.616, Loss:  0.846
# Epoch   1 Batch   18/134 - Train Accuracy:  0.612, Validation Accuracy:  0.625, Loss:  0.838
# Epoch   1 Batch   19/134 - Train Accuracy:  0.612, Validation Accuracy:  0.622, Loss:  0.826
# Epoch   1 Batch   20/134 - Train Accuracy:  0.616, Validation Accuracy:  0.619, Loss:  0.792
# Epoch   1 Batch   21/134 - Train Accuracy:  0.604, Validation Accuracy:  0.615, Loss:  0.824
# Epoch   1 Batch   22/134 - Train Accuracy:  0.589, Validation Accuracy:  0.621, Loss:  0.849
# Epoch   1 Batch   23/134 - Train Accuracy:  0.627, Validation Accuracy:  0.623, Loss:  0.755
# Epoch   1 Batch   24/134 - Train Accuracy:  0.595, Validation Accuracy:  0.627, Loss:  0.835
# Epoch   1 Batch   25/134 - Train Accuracy:  0.604, Validation Accuracy:  0.632, Loss:  0.799
# Epoch   1 Batch   26/134 - Train Accuracy:  0.604, Validation Accuracy:  0.625, Loss:  0.833
# Epoch   1 Batch   27/134 - Train Accuracy:  0.624, Validation Accuracy:  0.623, Loss:  0.794
# Epoch   1 Batch   28/134 - Train Accuracy:  0.617, Validation Accuracy:  0.629, Loss:  0.791
# Epoch   1 Batch   29/134 - Train Accuracy:  0.640, Validation Accuracy:  0.629, Loss:  0.740
# Epoch   1 Batch   30/134 - Train Accuracy:  0.632, Validation Accuracy:  0.630, Loss:  0.741
# Epoch   1 Batch   31/134 - Train Accuracy:  0.614, Validation Accuracy:  0.638, Loss:  0.772
# Epoch   1 Batch   32/134 - Train Accuracy:  0.644, Validation Accuracy:  0.638, Loss:  0.734
# Epoch   1 Batch   33/134 - Train Accuracy:  0.620, Validation Accuracy:  0.640, Loss:  0.776
# Epoch   1 Batch   34/134 - Train Accuracy:  0.624, Validation Accuracy:  0.643, Loss:  0.783
# Epoch   1 Batch   35/134 - Train Accuracy:  0.642, Validation Accuracy:  0.639, Loss:  0.734
# Epoch   1 Batch   36/134 - Train Accuracy:  0.637, Validation Accuracy:  0.648, Loss:  0.750
# Epoch   1 Batch   37/134 - Train Accuracy:  0.626, Validation Accuracy:  0.651, Loss:  0.759
# Epoch   1 Batch   38/134 - Train Accuracy:  0.636, Validation Accuracy:  0.646, Loss:  0.742
# Epoch   1 Batch   39/134 - Train Accuracy:  0.635, Validation Accuracy:  0.641, Loss:  0.738
# Epoch   1 Batch   40/134 - Train Accuracy:  0.634, Validation Accuracy:  0.645, Loss:  0.732
# Epoch   1 Batch   41/134 - Train Accuracy:  0.634, Validation Accuracy:  0.653, Loss:  0.731
# Epoch   1 Batch   42/134 - Train Accuracy:  0.623, Validation Accuracy:  0.646, Loss:  0.728
# Epoch   1 Batch   43/134 - Train Accuracy:  0.635, Validation Accuracy:  0.656, Loss:  0.736
# Epoch   1 Batch   44/134 - Train Accuracy:  0.636, Validation Accuracy:  0.655, Loss:  0.725
# Epoch   1 Batch   45/134 - Train Accuracy:  0.653, Validation Accuracy:  0.661, Loss:  0.706
# Epoch   1 Batch   46/134 - Train Accuracy:  0.665, Validation Accuracy:  0.657, Loss:  0.692
# Epoch   1 Batch   47/134 - Train Accuracy:  0.646, Validation Accuracy:  0.661, Loss:  0.711
# Epoch   1 Batch   48/134 - Train Accuracy:  0.653, Validation Accuracy:  0.669, Loss:  0.708
# Epoch   1 Batch   49/134 - Train Accuracy:  0.666, Validation Accuracy:  0.666, Loss:  0.691
# Epoch   1 Batch   50/134 - Train Accuracy:  0.648, Validation Accuracy:  0.667, Loss:  0.702
# Epoch   1 Batch   51/134 - Train Accuracy:  0.648, Validation Accuracy:  0.669, Loss:  0.694
# Epoch   1 Batch   52/134 - Train Accuracy:  0.657, Validation Accuracy:  0.670, Loss:  0.696
# Epoch   1 Batch   53/134 - Train Accuracy:  0.654, Validation Accuracy:  0.667, Loss:  0.687
# Epoch   1 Batch   54/134 - Train Accuracy:  0.647, Validation Accuracy:  0.661, Loss:  0.688
# Epoch   1 Batch   55/134 - Train Accuracy:  0.655, Validation Accuracy:  0.661, Loss:  0.689
# Epoch   1 Batch   56/134 - Train Accuracy:  0.675, Validation Accuracy:  0.672, Loss:  0.652
# Epoch   1 Batch   57/134 - Train Accuracy:  0.653, Validation Accuracy:  0.672, Loss:  0.677
# Epoch   1 Batch   58/134 - Train Accuracy:  0.664, Validation Accuracy:  0.673, Loss:  0.661
# Epoch   1 Batch   59/134 - Train Accuracy:  0.650, Validation Accuracy:  0.680, Loss:  0.703
# Epoch   1 Batch   60/134 - Train Accuracy:  0.663, Validation Accuracy:  0.677, Loss:  0.659
# Epoch   1 Batch   61/134 - Train Accuracy:  0.673, Validation Accuracy:  0.675, Loss:  0.652
# Epoch   1 Batch   62/134 - Train Accuracy:  0.678, Validation Accuracy:  0.679, Loss:  0.648
# Epoch   1 Batch   63/134 - Train Accuracy:  0.676, Validation Accuracy:  0.680, Loss:  0.655
# Epoch   1 Batch   64/134 - Train Accuracy:  0.662, Validation Accuracy:  0.682, Loss:  0.658
# Epoch   1 Batch   65/134 - Train Accuracy:  0.671, Validation Accuracy:  0.684, Loss:  0.650
# Epoch   1 Batch   66/134 - Train Accuracy:  0.672, Validation Accuracy:  0.678, Loss:  0.635
# Epoch   1 Batch   67/134 - Train Accuracy:  0.648, Validation Accuracy:  0.689, Loss:  0.690
# Epoch   1 Batch   68/134 - Train Accuracy:  0.672, Validation Accuracy:  0.689, Loss:  0.675
# Epoch   1 Batch   69/134 - Train Accuracy:  0.677, Validation Accuracy:  0.688, Loss:  0.637
# Epoch   1 Batch   70/134 - Train Accuracy:  0.676, Validation Accuracy:  0.685, Loss:  0.627
# Epoch   1 Batch   71/134 - Train Accuracy:  0.683, Validation Accuracy:  0.687, Loss:  0.629
# Epoch   1 Batch   72/134 - Train Accuracy:  0.679, Validation Accuracy:  0.676, Loss:  0.628
# Epoch   1 Batch   73/134 - Train Accuracy:  0.683, Validation Accuracy:  0.689, Loss:  0.613
# Epoch   1 Batch   74/134 - Train Accuracy:  0.688, Validation Accuracy:  0.696, Loss:  0.641
# Epoch   1 Batch   75/134 - Train Accuracy:  0.703, Validation Accuracy:  0.691, Loss:  0.606
# Epoch   1 Batch   76/134 - Train Accuracy:  0.691, Validation Accuracy:  0.690, Loss:  0.614
# Epoch   1 Batch   77/134 - Train Accuracy:  0.706, Validation Accuracy:  0.699, Loss:  0.589
# Epoch   1 Batch   78/134 - Train Accuracy:  0.685, Validation Accuracy:  0.694, Loss:  0.617
# Epoch   1 Batch   79/134 - Train Accuracy:  0.678, Validation Accuracy:  0.691, Loss:  0.618
# Epoch   1 Batch   80/134 - Train Accuracy:  0.687, Validation Accuracy:  0.699, Loss:  0.610
# Epoch   1 Batch   81/134 - Train Accuracy:  0.700, Validation Accuracy:  0.703, Loss:  0.605
# Epoch   1 Batch   82/134 - Train Accuracy:  0.708, Validation Accuracy:  0.697, Loss:  0.568
# Epoch   1 Batch   83/134 - Train Accuracy:  0.677, Validation Accuracy:  0.700, Loss:  0.610
# Epoch   1 Batch   84/134 - Train Accuracy:  0.702, Validation Accuracy:  0.708, Loss:  0.600
# Epoch   1 Batch   85/134 - Train Accuracy:  0.715, Validation Accuracy:  0.707, Loss:  0.603
# Epoch   1 Batch   86/134 - Train Accuracy:  0.695, Validation Accuracy:  0.705, Loss:  0.589
# Epoch   1 Batch   87/134 - Train Accuracy:  0.698, Validation Accuracy:  0.704, Loss:  0.609
# Epoch   1 Batch   88/134 - Train Accuracy:  0.712, Validation Accuracy:  0.707, Loss:  0.557
# Epoch   1 Batch   89/134 - Train Accuracy:  0.689, Validation Accuracy:  0.699, Loss:  0.590
# Epoch   1 Batch   90/134 - Train Accuracy:  0.695, Validation Accuracy:  0.700, Loss:  0.593
# Epoch   1 Batch   91/134 - Train Accuracy:  0.738, Validation Accuracy:  0.708, Loss:  0.509
# Epoch   1 Batch   92/134 - Train Accuracy:  0.709, Validation Accuracy:  0.712, Loss:  0.571
# Epoch   1 Batch   93/134 - Train Accuracy:  0.708, Validation Accuracy:  0.707, Loss:  0.571
# Epoch   1 Batch   94/134 - Train Accuracy:  0.698, Validation Accuracy:  0.709, Loss:  0.565
# Epoch   1 Batch   95/134 - Train Accuracy:  0.702, Validation Accuracy:  0.713, Loss:  0.572
# Epoch   1 Batch   96/134 - Train Accuracy:  0.711, Validation Accuracy:  0.712, Loss:  0.580
# Epoch   1 Batch   97/134 - Train Accuracy:  0.697, Validation Accuracy:  0.707, Loss:  0.572
# Epoch   1 Batch   98/134 - Train Accuracy:  0.700, Validation Accuracy:  0.711, Loss:  0.598
# Epoch   1 Batch   99/134 - Train Accuracy:  0.708, Validation Accuracy:  0.718, Loss:  0.570
# Epoch   1 Batch  100/134 - Train Accuracy:  0.697, Validation Accuracy:  0.707, Loss:  0.567
# Epoch   1 Batch  101/134 - Train Accuracy:  0.697, Validation Accuracy:  0.713, Loss:  0.603
# Epoch   1 Batch  102/134 - Train Accuracy:  0.703, Validation Accuracy:  0.709, Loss:  0.551
# Epoch   1 Batch  103/134 - Train Accuracy:  0.719, Validation Accuracy:  0.719, Loss:  0.540
# Epoch   1 Batch  104/134 - Train Accuracy:  0.714, Validation Accuracy:  0.719, Loss:  0.542
# Epoch   1 Batch  105/134 - Train Accuracy:  0.708, Validation Accuracy:  0.715, Loss:  0.559
# Epoch   1 Batch  106/134 - Train Accuracy:  0.720, Validation Accuracy:  0.721, Loss:  0.552
# Epoch   1 Batch  107/134 - Train Accuracy:  0.734, Validation Accuracy:  0.725, Loss:  0.529
# Epoch   1 Batch  108/134 - Train Accuracy:  0.693, Validation Accuracy:  0.715, Loss:  0.572
# Epoch   1 Batch  109/134 - Train Accuracy:  0.730, Validation Accuracy:  0.718, Loss:  0.516
# Epoch   1 Batch  110/134 - Train Accuracy:  0.729, Validation Accuracy:  0.718, Loss:  0.533
# Epoch   1 Batch  111/134 - Train Accuracy:  0.713, Validation Accuracy:  0.720, Loss:  0.547
# Epoch   1 Batch  112/134 - Train Accuracy:  0.718, Validation Accuracy:  0.725, Loss:  0.535
# Epoch   1 Batch  113/134 - Train Accuracy:  0.751, Validation Accuracy:  0.724, Loss:  0.473
# Epoch   1 Batch  114/134 - Train Accuracy:  0.722, Validation Accuracy:  0.728, Loss:  0.530
# Epoch   1 Batch  115/134 - Train Accuracy:  0.705, Validation Accuracy:  0.721, Loss:  0.557
# Epoch   1 Batch  116/134 - Train Accuracy:  0.721, Validation Accuracy:  0.723, Loss:  0.536
# Epoch   1 Batch  117/134 - Train Accuracy:  0.723, Validation Accuracy:  0.732, Loss:  0.524
# Epoch   1 Batch  118/134 - Train Accuracy:  0.735, Validation Accuracy:  0.731, Loss:  0.521
# Epoch   1 Batch  119/134 - Train Accuracy:  0.748, Validation Accuracy:  0.730, Loss:  0.477
# Epoch   1 Batch  120/134 - Train Accuracy:  0.726, Validation Accuracy:  0.728, Loss:  0.525
# Epoch   1 Batch  121/134 - Train Accuracy:  0.729, Validation Accuracy:  0.734, Loss:  0.511
# Epoch   1 Batch  122/134 - Train Accuracy:  0.722, Validation Accuracy:  0.733, Loss:  0.523
# Epoch   1 Batch  123/134 - Train Accuracy:  0.730, Validation Accuracy:  0.739, Loss:  0.510
# Epoch   1 Batch  124/134 - Train Accuracy:  0.752, Validation Accuracy:  0.736, Loss:  0.482
# Epoch   1 Batch  125/134 - Train Accuracy:  0.732, Validation Accuracy:  0.738, Loss:  0.511
# Epoch   1 Batch  126/134 - Train Accuracy:  0.723, Validation Accuracy:  0.740, Loss:  0.515
# Epoch   1 Batch  127/134 - Train Accuracy:  0.737, Validation Accuracy:  0.739, Loss:  0.490
# Epoch   1 Batch  128/134 - Train Accuracy:  0.731, Validation Accuracy:  0.737, Loss:  0.513
# Epoch   1 Batch  129/134 - Train Accuracy:  0.733, Validation Accuracy:  0.743, Loss:  0.505
# Epoch   1 Batch  130/134 - Train Accuracy:  0.739, Validation Accuracy:  0.744, Loss:  0.505
# Epoch   1 Batch  131/134 - Train Accuracy:  0.727, Validation Accuracy:  0.748, Loss:  0.525
# Epoch   1 Batch  132/134 - Train Accuracy:  0.739, Validation Accuracy:  0.742, Loss:  0.488
# Epoch   2 Batch    0/134 - Train Accuracy:  0.736, Validation Accuracy:  0.743, Loss:  0.496
# Epoch   2 Batch    1/134 - Train Accuracy:  0.733, Validation Accuracy:  0.752, Loss:  0.520
# Epoch   2 Batch    2/134 - Train Accuracy:  0.742, Validation Accuracy:  0.750, Loss:  0.482
# Epoch   2 Batch    3/134 - Train Accuracy:  0.745, Validation Accuracy:  0.747, Loss:  0.484
# Epoch   2 Batch    4/134 - Train Accuracy:  0.756, Validation Accuracy:  0.751, Loss:  0.491
# Epoch   2 Batch    5/134 - Train Accuracy:  0.743, Validation Accuracy:  0.750, Loss:  0.495
# Epoch   2 Batch    6/134 - Train Accuracy:  0.753, Validation Accuracy:  0.748, Loss:  0.459
# Epoch   2 Batch    7/134 - Train Accuracy:  0.742, Validation Accuracy:  0.752, Loss:  0.474
# Epoch   2 Batch    8/134 - Train Accuracy:  0.750, Validation Accuracy:  0.754, Loss:  0.468
# Epoch   2 Batch    9/134 - Train Accuracy:  0.765, Validation Accuracy:  0.756, Loss:  0.448
# Epoch   2 Batch   10/134 - Train Accuracy:  0.750, Validation Accuracy:  0.758, Loss:  0.476
# Epoch   2 Batch   11/134 - Train Accuracy:  0.745, Validation Accuracy:  0.749, Loss:  0.474
# Epoch   2 Batch   12/134 - Train Accuracy:  0.767, Validation Accuracy:  0.759, Loss:  0.456
# Epoch   2 Batch   13/134 - Train Accuracy:  0.735, Validation Accuracy:  0.755, Loss:  0.476
# Epoch   2 Batch   14/134 - Train Accuracy:  0.762, Validation Accuracy:  0.765, Loss:  0.467
# Epoch   2 Batch   15/134 - Train Accuracy:  0.741, Validation Accuracy:  0.751, Loss:  0.466
# Epoch   2 Batch   16/134 - Train Accuracy:  0.759, Validation Accuracy:  0.759, Loss:  0.453
# Epoch   2 Batch   17/134 - Train Accuracy:  0.747, Validation Accuracy:  0.764, Loss:  0.471
# Epoch   2 Batch   18/134 - Train Accuracy:  0.749, Validation Accuracy:  0.752, Loss:  0.466
# Epoch   2 Batch   19/134 - Train Accuracy:  0.752, Validation Accuracy:  0.763, Loss:  0.456
# Epoch   2 Batch   20/134 - Train Accuracy:  0.781, Validation Accuracy:  0.769, Loss:  0.437
# Epoch   2 Batch   21/134 - Train Accuracy:  0.756, Validation Accuracy:  0.762, Loss:  0.458
# Epoch   2 Batch   22/134 - Train Accuracy:  0.756, Validation Accuracy:  0.770, Loss:  0.472
# Epoch   2 Batch   23/134 - Train Accuracy:  0.785, Validation Accuracy:  0.761, Loss:  0.419
# Epoch   2 Batch   24/134 - Train Accuracy:  0.753, Validation Accuracy:  0.768, Loss:  0.468
# Epoch   2 Batch   25/134 - Train Accuracy:  0.749, Validation Accuracy:  0.768, Loss:  0.440
# Epoch   2 Batch   26/134 - Train Accuracy:  0.751, Validation Accuracy:  0.768, Loss:  0.473
# Epoch   2 Batch   27/134 - Train Accuracy:  0.773, Validation Accuracy:  0.772, Loss:  0.448
# Epoch   2 Batch   28/134 - Train Accuracy:  0.769, Validation Accuracy:  0.778, Loss:  0.447
# Epoch   2 Batch   29/134 - Train Accuracy:  0.779, Validation Accuracy:  0.771, Loss:  0.407
# Epoch   2 Batch   30/134 - Train Accuracy:  0.778, Validation Accuracy:  0.772, Loss:  0.418
# Epoch   2 Batch   31/134 - Train Accuracy:  0.769, Validation Accuracy:  0.773, Loss:  0.434
# Epoch   2 Batch   32/134 - Train Accuracy:  0.773, Validation Accuracy:  0.780, Loss:  0.414
# Epoch   2 Batch   33/134 - Train Accuracy:  0.764, Validation Accuracy:  0.773, Loss:  0.444
# Epoch   2 Batch   34/134 - Train Accuracy:  0.765, Validation Accuracy:  0.775, Loss:  0.440
# Epoch   2 Batch   35/134 - Train Accuracy:  0.780, Validation Accuracy:  0.776, Loss:  0.418
# Epoch   2 Batch   36/134 - Train Accuracy:  0.776, Validation Accuracy:  0.778, Loss:  0.424
# Epoch   2 Batch   37/134 - Train Accuracy:  0.775, Validation Accuracy:  0.782, Loss:  0.426
# Epoch   2 Batch   38/134 - Train Accuracy:  0.773, Validation Accuracy:  0.775, Loss:  0.423
# Epoch   2 Batch   39/134 - Train Accuracy:  0.775, Validation Accuracy:  0.779, Loss:  0.420
# Epoch   2 Batch   40/134 - Train Accuracy:  0.773, Validation Accuracy:  0.777, Loss:  0.427
# Epoch   2 Batch   41/134 - Train Accuracy:  0.773, Validation Accuracy:  0.783, Loss:  0.427
# Epoch   2 Batch   42/134 - Train Accuracy:  0.772, Validation Accuracy:  0.780, Loss:  0.412
# Epoch   2 Batch   43/134 - Train Accuracy:  0.758, Validation Accuracy:  0.779, Loss:  0.420
# Epoch   2 Batch   44/134 - Train Accuracy:  0.783, Validation Accuracy:  0.784, Loss:  0.418
# Epoch   2 Batch   45/134 - Train Accuracy:  0.774, Validation Accuracy:  0.777, Loss:  0.400
# Epoch   2 Batch   46/134 - Train Accuracy:  0.784, Validation Accuracy:  0.777, Loss:  0.404
# Epoch   2 Batch   47/134 - Train Accuracy:  0.773, Validation Accuracy:  0.788, Loss:  0.408
# Epoch   2 Batch   48/134 - Train Accuracy:  0.770, Validation Accuracy:  0.775, Loss:  0.413
# Epoch   2 Batch   49/134 - Train Accuracy:  0.780, Validation Accuracy:  0.781, Loss:  0.405
# Epoch   2 Batch   50/134 - Train Accuracy:  0.771, Validation Accuracy:  0.790, Loss:  0.406
# Epoch   2 Batch   51/134 - Train Accuracy:  0.776, Validation Accuracy:  0.782, Loss:  0.403
# Epoch   2 Batch   52/134 - Train Accuracy:  0.768, Validation Accuracy:  0.793, Loss:  0.403
# Epoch   2 Batch   53/134 - Train Accuracy:  0.785, Validation Accuracy:  0.793, Loss:  0.395
# Epoch   2 Batch   54/134 - Train Accuracy:  0.773, Validation Accuracy:  0.793, Loss:  0.396
# Epoch   2 Batch   55/134 - Train Accuracy:  0.777, Validation Accuracy:  0.783, Loss:  0.400
# Epoch   2 Batch   56/134 - Train Accuracy:  0.791, Validation Accuracy:  0.797, Loss:  0.377
# Epoch   2 Batch   57/134 - Train Accuracy:  0.784, Validation Accuracy:  0.790, Loss:  0.394
# Epoch   2 Batch   58/134 - Train Accuracy:  0.789, Validation Accuracy:  0.791, Loss:  0.386
# Epoch   2 Batch   59/134 - Train Accuracy:  0.781, Validation Accuracy:  0.795, Loss:  0.410
# Epoch   2 Batch   60/134 - Train Accuracy:  0.781, Validation Accuracy:  0.787, Loss:  0.382
# Epoch   2 Batch   61/134 - Train Accuracy:  0.798, Validation Accuracy:  0.793, Loss:  0.383
# Epoch   2 Batch   62/134 - Train Accuracy:  0.788, Validation Accuracy:  0.794, Loss:  0.377
# Epoch   2 Batch   63/134 - Train Accuracy:  0.799, Validation Accuracy:  0.793, Loss:  0.384
# Epoch   2 Batch   64/134 - Train Accuracy:  0.786, Validation Accuracy:  0.794, Loss:  0.382
# Epoch   2 Batch   65/134 - Train Accuracy:  0.787, Validation Accuracy:  0.799, Loss:  0.379
# Epoch   2 Batch   66/134 - Train Accuracy:  0.799, Validation Accuracy:  0.799, Loss:  0.362
# Epoch   2 Batch   67/134 - Train Accuracy:  0.764, Validation Accuracy:  0.799, Loss:  0.405
# Epoch   2 Batch   68/134 - Train Accuracy:  0.798, Validation Accuracy:  0.799, Loss:  0.389
# Epoch   2 Batch   69/134 - Train Accuracy:  0.794, Validation Accuracy:  0.800, Loss:  0.366
# Epoch   2 Batch   70/134 - Train Accuracy:  0.788, Validation Accuracy:  0.805, Loss:  0.366
# Epoch   2 Batch   71/134 - Train Accuracy:  0.794, Validation Accuracy:  0.810, Loss:  0.355
# Epoch   2 Batch   72/134 - Train Accuracy:  0.792, Validation Accuracy:  0.805, Loss:  0.357
# Epoch   2 Batch   73/134 - Train Accuracy:  0.794, Validation Accuracy:  0.799, Loss:  0.359
# Epoch   2 Batch   74/134 - Train Accuracy:  0.792, Validation Accuracy:  0.809, Loss:  0.381
# Epoch   2 Batch   75/134 - Train Accuracy:  0.799, Validation Accuracy:  0.803, Loss:  0.364
# Epoch   2 Batch   76/134 - Train Accuracy:  0.811, Validation Accuracy:  0.804, Loss:  0.366
# Epoch   2 Batch   77/134 - Train Accuracy:  0.806, Validation Accuracy:  0.803, Loss:  0.347
# Epoch   2 Batch   78/134 - Train Accuracy:  0.788, Validation Accuracy:  0.809, Loss:  0.356
# Epoch   2 Batch   79/134 - Train Accuracy:  0.799, Validation Accuracy:  0.809, Loss:  0.365
# Epoch   2 Batch   80/134 - Train Accuracy:  0.798, Validation Accuracy:  0.800, Loss:  0.357
# Epoch   2 Batch   81/134 - Train Accuracy:  0.796, Validation Accuracy:  0.803, Loss:  0.354
# Epoch   2 Batch   82/134 - Train Accuracy:  0.811, Validation Accuracy:  0.815, Loss:  0.335
# Epoch   2 Batch   83/134 - Train Accuracy:  0.787, Validation Accuracy:  0.812, Loss:  0.352
# Epoch   2 Batch   84/134 - Train Accuracy:  0.804, Validation Accuracy:  0.813, Loss:  0.348
# Epoch   2 Batch   85/134 - Train Accuracy:  0.816, Validation Accuracy:  0.813, Loss:  0.347
# Epoch   2 Batch   86/134 - Train Accuracy:  0.812, Validation Accuracy:  0.815, Loss:  0.339
# Epoch   2 Batch   87/134 - Train Accuracy:  0.801, Validation Accuracy:  0.816, Loss:  0.348
# Epoch   2 Batch   88/134 - Train Accuracy:  0.822, Validation Accuracy:  0.815, Loss:  0.318
# Epoch   2 Batch   89/134 - Train Accuracy:  0.807, Validation Accuracy:  0.808, Loss:  0.338
# Epoch   2 Batch   90/134 - Train Accuracy:  0.797, Validation Accuracy:  0.809, Loss:  0.341
# Epoch   2 Batch   91/134 - Train Accuracy:  0.837, Validation Accuracy:  0.817, Loss:  0.291
# Epoch   2 Batch   92/134 - Train Accuracy:  0.820, Validation Accuracy:  0.819, Loss:  0.323
# Epoch   2 Batch   93/134 - Train Accuracy:  0.820, Validation Accuracy:  0.819, Loss:  0.322
# Epoch   2 Batch   94/134 - Train Accuracy:  0.813, Validation Accuracy:  0.822, Loss:  0.318
# Epoch   2 Batch   95/134 - Train Accuracy:  0.809, Validation Accuracy:  0.823, Loss:  0.330
# Epoch   2 Batch   96/134 - Train Accuracy:  0.818, Validation Accuracy:  0.814, Loss:  0.328
# Epoch   2 Batch   97/134 - Train Accuracy:  0.821, Validation Accuracy:  0.830, Loss:  0.331
# Epoch   2 Batch   98/134 - Train Accuracy:  0.807, Validation Accuracy:  0.827, Loss:  0.337
# Epoch   2 Batch   99/134 - Train Accuracy:  0.820, Validation Accuracy:  0.820, Loss:  0.315
# Epoch   2 Batch  100/134 - Train Accuracy:  0.819, Validation Accuracy:  0.823, Loss:  0.320
# Epoch   2 Batch  101/134 - Train Accuracy:  0.812, Validation Accuracy:  0.816, Loss:  0.339
# Epoch   2 Batch  102/134 - Train Accuracy:  0.817, Validation Accuracy:  0.829, Loss:  0.315
# Epoch   2 Batch  103/134 - Train Accuracy:  0.825, Validation Accuracy:  0.833, Loss:  0.301
# Epoch   2 Batch  104/134 - Train Accuracy:  0.829, Validation Accuracy:  0.824, Loss:  0.303
# Epoch   2 Batch  105/134 - Train Accuracy:  0.828, Validation Accuracy:  0.833, Loss:  0.315
# Epoch   2 Batch  106/134 - Train Accuracy:  0.829, Validation Accuracy:  0.836, Loss:  0.305
# Epoch   2 Batch  107/134 - Train Accuracy:  0.837, Validation Accuracy:  0.832, Loss:  0.294
# Epoch   2 Batch  108/134 - Train Accuracy:  0.820, Validation Accuracy:  0.838, Loss:  0.318
# Epoch   2 Batch  109/134 - Train Accuracy:  0.845, Validation Accuracy:  0.834, Loss:  0.289
# Epoch   2 Batch  110/134 - Train Accuracy:  0.846, Validation Accuracy:  0.836, Loss:  0.296
# Epoch   2 Batch  111/134 - Train Accuracy:  0.830, Validation Accuracy:  0.834, Loss:  0.301
# Epoch   2 Batch  112/134 - Train Accuracy:  0.837, Validation Accuracy:  0.839, Loss:  0.294
# Epoch   2 Batch  113/134 - Train Accuracy:  0.847, Validation Accuracy:  0.834, Loss:  0.269
# Epoch   2 Batch  114/134 - Train Accuracy:  0.842, Validation Accuracy:  0.839, Loss:  0.294
# Epoch   2 Batch  115/134 - Train Accuracy:  0.825, Validation Accuracy:  0.837, Loss:  0.304
# Epoch   2 Batch  116/134 - Train Accuracy:  0.840, Validation Accuracy:  0.842, Loss:  0.294
# Epoch   2 Batch  117/134 - Train Accuracy:  0.842, Validation Accuracy:  0.841, Loss:  0.284
# Epoch   2 Batch  118/134 - Train Accuracy:  0.839, Validation Accuracy:  0.846, Loss:  0.286
# Epoch   2 Batch  119/134 - Train Accuracy:  0.857, Validation Accuracy:  0.845, Loss:  0.263
# Epoch   2 Batch  120/134 - Train Accuracy:  0.846, Validation Accuracy:  0.850, Loss:  0.289
# Epoch   2 Batch  121/134 - Train Accuracy:  0.841, Validation Accuracy:  0.844, Loss:  0.278
# Epoch   2 Batch  122/134 - Train Accuracy:  0.834, Validation Accuracy:  0.845, Loss:  0.282
# Epoch   2 Batch  123/134 - Train Accuracy:  0.849, Validation Accuracy:  0.846, Loss:  0.275
# Epoch   2 Batch  124/134 - Train Accuracy:  0.856, Validation Accuracy:  0.837, Loss:  0.267
# Epoch   2 Batch  125/134 - Train Accuracy:  0.850, Validation Accuracy:  0.844, Loss:  0.285
# Epoch   2 Batch  126/134 - Train Accuracy:  0.827, Validation Accuracy:  0.844, Loss:  0.300
# Epoch   2 Batch  127/134 - Train Accuracy:  0.840, Validation Accuracy:  0.852, Loss:  0.285
# Epoch   2 Batch  128/134 - Train Accuracy:  0.831, Validation Accuracy:  0.848, Loss:  0.282
# Epoch   2 Batch  129/134 - Train Accuracy:  0.832, Validation Accuracy:  0.837, Loss:  0.293
# Epoch   2 Batch  130/134 - Train Accuracy:  0.842, Validation Accuracy:  0.848, Loss:  0.284
# Epoch   2 Batch  131/134 - Train Accuracy:  0.830, Validation Accuracy:  0.850, Loss:  0.285
# Epoch   2 Batch  132/134 - Train Accuracy:  0.854, Validation Accuracy:  0.853, Loss:  0.277
# Epoch   3 Batch    0/134 - Train Accuracy:  0.838, Validation Accuracy:  0.846, Loss:  0.265
# Epoch   3 Batch    1/134 - Train Accuracy:  0.848, Validation Accuracy:  0.856, Loss:  0.287
# Epoch   3 Batch    2/134 - Train Accuracy:  0.851, Validation Accuracy:  0.847, Loss:  0.258
# Epoch   3 Batch    3/134 - Train Accuracy:  0.862, Validation Accuracy:  0.856, Loss:  0.269
# Epoch   3 Batch    4/134 - Train Accuracy:  0.850, Validation Accuracy:  0.849, Loss:  0.260
# Epoch   3 Batch    5/134 - Train Accuracy:  0.857, Validation Accuracy:  0.856, Loss:  0.280
# Epoch   3 Batch    6/134 - Train Accuracy:  0.852, Validation Accuracy:  0.855, Loss:  0.244
# Epoch   3 Batch    7/134 - Train Accuracy:  0.861, Validation Accuracy:  0.854, Loss:  0.259
# Epoch   3 Batch    8/134 - Train Accuracy:  0.847, Validation Accuracy:  0.851, Loss:  0.250
# Epoch   3 Batch    9/134 - Train Accuracy:  0.865, Validation Accuracy:  0.858, Loss:  0.240
# Epoch   3 Batch   10/134 - Train Accuracy:  0.866, Validation Accuracy:  0.864, Loss:  0.257
# Epoch   3 Batch   11/134 - Train Accuracy:  0.867, Validation Accuracy:  0.863, Loss:  0.252
# Epoch   3 Batch   12/134 - Train Accuracy:  0.867, Validation Accuracy:  0.860, Loss:  0.240
# Epoch   3 Batch   13/134 - Train Accuracy:  0.840, Validation Accuracy:  0.860, Loss:  0.251
# Epoch   3 Batch   14/134 - Train Accuracy:  0.873, Validation Accuracy:  0.865, Loss:  0.245
# Epoch   3 Batch   15/134 - Train Accuracy:  0.859, Validation Accuracy:  0.865, Loss:  0.241
# Epoch   3 Batch   16/134 - Train Accuracy:  0.862, Validation Accuracy:  0.867, Loss:  0.236
# Epoch   3 Batch   17/134 - Train Accuracy:  0.853, Validation Accuracy:  0.868, Loss:  0.253
# Epoch   3 Batch   18/134 - Train Accuracy:  0.862, Validation Accuracy:  0.864, Loss:  0.247
# Epoch   3 Batch   19/134 - Train Accuracy:  0.865, Validation Accuracy:  0.869, Loss:  0.237
# Epoch   3 Batch   20/134 - Train Accuracy:  0.870, Validation Accuracy:  0.873, Loss:  0.231
# Epoch   3 Batch   21/134 - Train Accuracy:  0.865, Validation Accuracy:  0.867, Loss:  0.236
# Epoch   3 Batch   22/134 - Train Accuracy:  0.863, Validation Accuracy:  0.867, Loss:  0.246
# Epoch   3 Batch   23/134 - Train Accuracy:  0.872, Validation Accuracy:  0.866, Loss:  0.218
# Epoch   3 Batch   24/134 - Train Accuracy:  0.860, Validation Accuracy:  0.874, Loss:  0.242
# Epoch   3 Batch   25/134 - Train Accuracy:  0.860, Validation Accuracy:  0.872, Loss:  0.223
# Epoch   3 Batch   26/134 - Train Accuracy:  0.874, Validation Accuracy:  0.866, Loss:  0.242
# Epoch   3 Batch   27/134 - Train Accuracy:  0.875, Validation Accuracy:  0.874, Loss:  0.228
# Epoch   3 Batch   28/134 - Train Accuracy:  0.866, Validation Accuracy:  0.872, Loss:  0.234
# Epoch   3 Batch   29/134 - Train Accuracy:  0.880, Validation Accuracy:  0.878, Loss:  0.206
# Epoch   3 Batch   30/134 - Train Accuracy:  0.877, Validation Accuracy:  0.877, Loss:  0.215
# Epoch   3 Batch   31/134 - Train Accuracy:  0.877, Validation Accuracy:  0.874, Loss:  0.220
# Epoch   3 Batch   32/134 - Train Accuracy:  0.870, Validation Accuracy:  0.878, Loss:  0.214
# Epoch   3 Batch   33/134 - Train Accuracy:  0.869, Validation Accuracy:  0.876, Loss:  0.229
# Epoch   3 Batch   34/134 - Train Accuracy:  0.865, Validation Accuracy:  0.884, Loss:  0.233
# Epoch   3 Batch   35/134 - Train Accuracy:  0.882, Validation Accuracy:  0.877, Loss:  0.218
# Epoch   3 Batch   36/134 - Train Accuracy:  0.882, Validation Accuracy:  0.882, Loss:  0.216
# Epoch   3 Batch   37/134 - Train Accuracy:  0.871, Validation Accuracy:  0.880, Loss:  0.218
# Epoch   3 Batch   38/134 - Train Accuracy:  0.880, Validation Accuracy:  0.876, Loss:  0.213
# Epoch   3 Batch   39/134 - Train Accuracy:  0.872, Validation Accuracy:  0.875, Loss:  0.211
# Epoch   3 Batch   40/134 - Train Accuracy:  0.880, Validation Accuracy:  0.875, Loss:  0.215
# Epoch   3 Batch   41/134 - Train Accuracy:  0.878, Validation Accuracy:  0.879, Loss:  0.213
# Epoch   3 Batch   42/134 - Train Accuracy:  0.879, Validation Accuracy:  0.881, Loss:  0.207
# Epoch   3 Batch   43/134 - Train Accuracy:  0.869, Validation Accuracy:  0.883, Loss:  0.213
# Epoch   3 Batch   44/134 - Train Accuracy:  0.888, Validation Accuracy:  0.876, Loss:  0.210
# Epoch   3 Batch   45/134 - Train Accuracy:  0.886, Validation Accuracy:  0.884, Loss:  0.199
# Epoch   3 Batch   46/134 - Train Accuracy:  0.885, Validation Accuracy:  0.882, Loss:  0.204
# Epoch   3 Batch   47/134 - Train Accuracy:  0.876, Validation Accuracy:  0.889, Loss:  0.205
# Epoch   3 Batch   48/134 - Train Accuracy:  0.880, Validation Accuracy:  0.881, Loss:  0.204
# Epoch   3 Batch   49/134 - Train Accuracy:  0.883, Validation Accuracy:  0.881, Loss:  0.199
# Epoch   3 Batch   50/134 - Train Accuracy:  0.881, Validation Accuracy:  0.887, Loss:  0.204
# Epoch   3 Batch   51/134 - Train Accuracy:  0.884, Validation Accuracy:  0.886, Loss:  0.205
# Epoch   3 Batch   52/134 - Train Accuracy:  0.884, Validation Accuracy:  0.888, Loss:  0.195
# Epoch   3 Batch   53/134 - Train Accuracy:  0.891, Validation Accuracy:  0.889, Loss:  0.197
# Epoch   3 Batch   54/134 - Train Accuracy:  0.880, Validation Accuracy:  0.886, Loss:  0.196
# Epoch   3 Batch   55/134 - Train Accuracy:  0.882, Validation Accuracy:  0.890, Loss:  0.199
# Epoch   3 Batch   56/134 - Train Accuracy:  0.884, Validation Accuracy:  0.894, Loss:  0.188
# Epoch   3 Batch   57/134 - Train Accuracy:  0.890, Validation Accuracy:  0.897, Loss:  0.191
# Epoch   3 Batch   58/134 - Train Accuracy:  0.894, Validation Accuracy:  0.895, Loss:  0.182
# Epoch   3 Batch   59/134 - Train Accuracy:  0.876, Validation Accuracy:  0.890, Loss:  0.202
# Epoch   3 Batch   60/134 - Train Accuracy:  0.890, Validation Accuracy:  0.895, Loss:  0.186
# Epoch   3 Batch   61/134 - Train Accuracy:  0.891, Validation Accuracy:  0.896, Loss:  0.180
# Epoch   3 Batch   62/134 - Train Accuracy:  0.880, Validation Accuracy:  0.895, Loss:  0.184
# Epoch   3 Batch   63/134 - Train Accuracy:  0.888, Validation Accuracy:  0.894, Loss:  0.184
# Epoch   3 Batch   64/134 - Train Accuracy:  0.879, Validation Accuracy:  0.898, Loss:  0.189
# Epoch   3 Batch   65/134 - Train Accuracy:  0.881, Validation Accuracy:  0.896, Loss:  0.187
# Epoch   3 Batch   66/134 - Train Accuracy:  0.889, Validation Accuracy:  0.893, Loss:  0.174
# Epoch   3 Batch   67/134 - Train Accuracy:  0.873, Validation Accuracy:  0.899, Loss:  0.198
# Epoch   3 Batch   68/134 - Train Accuracy:  0.889, Validation Accuracy:  0.894, Loss:  0.193
# Epoch   3 Batch   69/134 - Train Accuracy:  0.886, Validation Accuracy:  0.895, Loss:  0.183
# Epoch   3 Batch   70/134 - Train Accuracy:  0.883, Validation Accuracy:  0.898, Loss:  0.177
# Epoch   3 Batch   71/134 - Train Accuracy:  0.900, Validation Accuracy:  0.899, Loss:  0.170
# Epoch   3 Batch   72/134 - Train Accuracy:  0.894, Validation Accuracy:  0.900, Loss:  0.174
# Epoch   3 Batch   73/134 - Train Accuracy:  0.898, Validation Accuracy:  0.902, Loss:  0.176
# Epoch   3 Batch   74/134 - Train Accuracy:  0.886, Validation Accuracy:  0.901, Loss:  0.181
# Epoch   3 Batch   75/134 - Train Accuracy:  0.899, Validation Accuracy:  0.903, Loss:  0.168
# Epoch   3 Batch   76/134 - Train Accuracy:  0.907, Validation Accuracy:  0.899, Loss:  0.164
# Epoch   3 Batch   77/134 - Train Accuracy:  0.898, Validation Accuracy:  0.906, Loss:  0.166
# Epoch   3 Batch   78/134 - Train Accuracy:  0.900, Validation Accuracy:  0.908, Loss:  0.165
# Epoch   3 Batch   79/134 - Train Accuracy:  0.893, Validation Accuracy:  0.899, Loss:  0.173
# Epoch   3 Batch   80/134 - Train Accuracy:  0.896, Validation Accuracy:  0.906, Loss:  0.166
# Epoch   3 Batch   81/134 - Train Accuracy:  0.897, Validation Accuracy:  0.901, Loss:  0.171
# Epoch   3 Batch   82/134 - Train Accuracy:  0.904, Validation Accuracy:  0.902, Loss:  0.157
# Epoch   3 Batch   83/134 - Train Accuracy:  0.897, Validation Accuracy:  0.903, Loss:  0.174
# Epoch   3 Batch   84/134 - Train Accuracy:  0.899, Validation Accuracy:  0.905, Loss:  0.164
# Epoch   3 Batch   85/134 - Train Accuracy:  0.905, Validation Accuracy:  0.906, Loss:  0.162
# Epoch   3 Batch   86/134 - Train Accuracy:  0.903, Validation Accuracy:  0.902, Loss:  0.158
# Epoch   3 Batch   87/134 - Train Accuracy:  0.887, Validation Accuracy:  0.908, Loss:  0.177
# Epoch   3 Batch   88/134 - Train Accuracy:  0.905, Validation Accuracy:  0.903, Loss:  0.150
# Epoch   3 Batch   89/134 - Train Accuracy:  0.904, Validation Accuracy:  0.911, Loss:  0.159
# Epoch   3 Batch   90/134 - Train Accuracy:  0.887, Validation Accuracy:  0.907, Loss:  0.164
# Epoch   3 Batch   91/134 - Train Accuracy:  0.919, Validation Accuracy:  0.912, Loss:  0.137
# Epoch   3 Batch   92/134 - Train Accuracy:  0.906, Validation Accuracy:  0.911, Loss:  0.151
# Epoch   3 Batch   93/134 - Train Accuracy:  0.905, Validation Accuracy:  0.910, Loss:  0.149
# Epoch   3 Batch   94/134 - Train Accuracy:  0.900, Validation Accuracy:  0.908, Loss:  0.150
# Epoch   3 Batch   95/134 - Train Accuracy:  0.904, Validation Accuracy:  0.910, Loss:  0.155
# Epoch   3 Batch   96/134 - Train Accuracy:  0.908, Validation Accuracy:  0.910, Loss:  0.152
# Epoch   3 Batch   97/134 - Train Accuracy:  0.895, Validation Accuracy:  0.908, Loss:  0.153
# Epoch   3 Batch   98/134 - Train Accuracy:  0.897, Validation Accuracy:  0.912, Loss:  0.162
# Epoch   3 Batch   99/134 - Train Accuracy:  0.902, Validation Accuracy:  0.909, Loss:  0.148
# Epoch   3 Batch  100/134 - Train Accuracy:  0.901, Validation Accuracy:  0.911, Loss:  0.151
# Epoch   3 Batch  101/134 - Train Accuracy:  0.896, Validation Accuracy:  0.911, Loss:  0.160
# Epoch   3 Batch  102/134 - Train Accuracy:  0.893, Validation Accuracy:  0.909, Loss:  0.147
# Epoch   3 Batch  103/134 - Train Accuracy:  0.909, Validation Accuracy:  0.914, Loss:  0.144
# Epoch   3 Batch  104/134 - Train Accuracy:  0.914, Validation Accuracy:  0.915, Loss:  0.139
# Epoch   3 Batch  105/134 - Train Accuracy:  0.906, Validation Accuracy:  0.913, Loss:  0.149
# Epoch   3 Batch  106/134 - Train Accuracy:  0.904, Validation Accuracy:  0.916, Loss:  0.146
# Epoch   3 Batch  107/134 - Train Accuracy:  0.918, Validation Accuracy:  0.916, Loss:  0.141
# Epoch   3 Batch  108/134 - Train Accuracy:  0.908, Validation Accuracy:  0.919, Loss:  0.148
# Epoch   3 Batch  109/134 - Train Accuracy:  0.919, Validation Accuracy:  0.914, Loss:  0.136
# Epoch   3 Batch  110/134 - Train Accuracy:  0.918, Validation Accuracy:  0.912, Loss:  0.140
# Epoch   3 Batch  111/134 - Train Accuracy:  0.905, Validation Accuracy:  0.917, Loss:  0.144
# Epoch   3 Batch  112/134 - Train Accuracy:  0.909, Validation Accuracy:  0.915, Loss:  0.138
# Epoch   3 Batch  113/134 - Train Accuracy:  0.920, Validation Accuracy:  0.913, Loss:  0.128
# Epoch   3 Batch  114/134 - Train Accuracy:  0.921, Validation Accuracy:  0.914, Loss:  0.135
# Epoch   3 Batch  115/134 - Train Accuracy:  0.902, Validation Accuracy:  0.912, Loss:  0.139
# Epoch   3 Batch  116/134 - Train Accuracy:  0.910, Validation Accuracy:  0.911, Loss:  0.137
# ...
# Epoch   8 Batch   95/134 - Train Accuracy:  0.971, Validation Accuracy:  0.971, Loss:  0.031
# Epoch   8 Batch   96/134 - Train Accuracy:  0.967, Validation Accuracy:  0.970, Loss:  0.029
# Epoch   8 Batch   97/134 - Train Accuracy:  0.965, Validation Accuracy:  0.971, Loss:  0.030
# Epoch   8 Batch   98/134 - Train Accuracy:  0.969, Validation Accuracy:  0.975, Loss:  0.031
# Epoch   8 Batch   99/134 - Train Accuracy:  0.970, Validation Accuracy:  0.972, Loss:  0.030
# Epoch   8 Batch  100/134 - Train Accuracy:  0.968, Validation Accuracy:  0.971, Loss:  0.031
# Epoch   8 Batch  101/134 - Train Accuracy:  0.967, Validation Accuracy:  0.970, Loss:  0.032
# Epoch   8 Batch  102/134 - Train Accuracy:  0.969, Validation Accuracy:  0.972, Loss:  0.031
# Epoch   8 Batch  103/134 - Train Accuracy:  0.971, Validation Accuracy:  0.971, Loss:  0.031
# Epoch   8 Batch  104/134 - Train Accuracy:  0.967, Validation Accuracy:  0.969, Loss:  0.028
# Epoch   8 Batch  105/134 - Train Accuracy:  0.970, Validation Accuracy:  0.969, Loss:  0.036
# Epoch   8 Batch  106/134 - Train Accuracy:  0.969, Validation Accuracy:  0.969, Loss:  0.030
# Epoch   8 Batch  107/134 - Train Accuracy:  0.961, Validation Accuracy:  0.972, Loss:  0.033
# Epoch   8 Batch  108/134 - Train Accuracy:  0.969, Validation Accuracy:  0.973, Loss:  0.030
# Epoch   8 Batch  109/134 - Train Accuracy:  0.971, Validation Accuracy:  0.974, Loss:  0.028
# Epoch   8 Batch  110/134 - Train Accuracy:  0.971, Validation Accuracy:  0.971, Loss:  0.029
# Epoch   8 Batch  111/134 - Train Accuracy:  0.959, Validation Accuracy:  0.969, Loss:  0.032
# Epoch   8 Batch  112/134 - Train Accuracy:  0.969, Validation Accuracy:  0.970, Loss:  0.031
# Epoch   8 Batch  113/134 - Train Accuracy:  0.973, Validation Accuracy:  0.972, Loss:  0.032
# Epoch   8 Batch  114/134 - Train Accuracy:  0.972, Validation Accuracy:  0.974, Loss:  0.027
# Epoch   8 Batch  115/134 - Train Accuracy:  0.968, Validation Accuracy:  0.973, Loss:  0.028
# Epoch   8 Batch  116/134 - Train Accuracy:  0.970, Validation Accuracy:  0.971, Loss:  0.032
# Epoch   8 Batch  117/134 - Train Accuracy:  0.980, Validation Accuracy:  0.972, Loss:  0.025
# Epoch   8 Batch  118/134 - Train Accuracy:  0.975, Validation Accuracy:  0.973, Loss:  0.029
# Epoch   8 Batch  119/134 - Train Accuracy:  0.972, Validation Accuracy:  0.970, Loss:  0.027
# Epoch   8 Batch  120/134 - Train Accuracy:  0.968, Validation Accuracy:  0.972, Loss:  0.034
# Epoch   8 Batch  121/134 - Train Accuracy:  0.967, Validation Accuracy:  0.971, Loss:  0.028
# Epoch   8 Batch  122/134 - Train Accuracy:  0.966, Validation Accuracy:  0.973, Loss:  0.030
# Epoch   8 Batch  123/134 - Train Accuracy:  0.971, Validation Accuracy:  0.973, Loss:  0.027
# Epoch   8 Batch  124/134 - Train Accuracy:  0.968, Validation Accuracy:  0.969, Loss:  0.027
# Epoch   8 Batch  125/134 - Train Accuracy:  0.976, Validation Accuracy:  0.972, Loss:  0.024
# Epoch   8 Batch  126/134 - Train Accuracy:  0.970, Validation Accuracy:  0.972, Loss:  0.029
# Epoch   8 Batch  127/134 - Train Accuracy:  0.968, Validation Accuracy:  0.972, Loss:  0.028
# Epoch   8 Batch  128/134 - Train Accuracy:  0.965, Validation Accuracy:  0.969, Loss:  0.033
# Epoch   8 Batch  129/134 - Train Accuracy:  0.966, Validation Accuracy:  0.971, Loss:  0.029
# Epoch   8 Batch  130/134 - Train Accuracy:  0.969, Validation Accuracy:  0.973, Loss:  0.027
# Epoch   8 Batch  131/134 - Train Accuracy:  0.962, Validation Accuracy:  0.972, Loss:  0.030
# Epoch   8 Batch  132/134 - Train Accuracy:  0.971, Validation Accuracy:  0.973, Loss:  0.026
# Epoch   9 Batch    0/134 - Train Accuracy:  0.969, Validation Accuracy:  0.972, Loss:  0.027
# Epoch   9 Batch    1/134 - Train Accuracy:  0.966, Validation Accuracy:  0.973, Loss:  0.030
# Epoch   9 Batch    2/134 - Train Accuracy:  0.970, Validation Accuracy:  0.976, Loss:  0.027
# Epoch   9 Batch    3/134 - Train Accuracy:  0.968, Validation Accuracy:  0.974, Loss:  0.029
# Epoch   9 Batch    4/134 - Train Accuracy:  0.972, Validation Accuracy:  0.973, Loss:  0.027
# Epoch   9 Batch    5/134 - Train Accuracy:  0.969, Validation Accuracy:  0.973, Loss:  0.032
# Epoch   9 Batch    6/134 - Train Accuracy:  0.973, Validation Accuracy:  0.972, Loss:  0.025
# Epoch   9 Batch    7/134 - Train Accuracy:  0.972, Validation Accuracy:  0.971, Loss:  0.027
# Epoch   9 Batch    8/134 - Train Accuracy:  0.970, Validation Accuracy:  0.974, Loss:  0.026
# Epoch   9 Batch    9/134 - Train Accuracy:  0.979, Validation Accuracy:  0.974, Loss:  0.023
# Epoch   9 Batch   10/134 - Train Accuracy:  0.967, Validation Accuracy:  0.973, Loss:  0.029
# Epoch   9 Batch   11/134 - Train Accuracy:  0.967, Validation Accuracy:  0.971, Loss:  0.028
# Epoch   9 Batch   12/134 - Train Accuracy:  0.969, Validation Accuracy:  0.973, Loss:  0.028
# Epoch   9 Batch   13/134 - Train Accuracy:  0.963, Validation Accuracy:  0.972, Loss:  0.027
# Epoch   9 Batch   14/134 - Train Accuracy:  0.973, Validation Accuracy:  0.971, Loss:  0.029
# Epoch   9 Batch   15/134 - Train Accuracy:  0.969, Validation Accuracy:  0.973, Loss:  0.026
# Epoch   9 Batch   16/134 - Train Accuracy:  0.972, Validation Accuracy:  0.970, Loss:  0.023
# Epoch   9 Batch   17/134 - Train Accuracy:  0.971, Validation Accuracy:  0.973, Loss:  0.032
# Epoch   9 Batch   18/134 - Train Accuracy:  0.968, Validation Accuracy:  0.973, Loss:  0.028
# Epoch   9 Batch   19/134 - Train Accuracy:  0.969, Validation Accuracy:  0.970, Loss:  0.027
# Epoch   9 Batch   20/134 - Train Accuracy:  0.969, Validation Accuracy:  0.970, Loss:  0.027
# Epoch   9 Batch   21/134 - Train Accuracy:  0.966, Validation Accuracy:  0.971, Loss:  0.028
# Epoch   9 Batch   22/134 - Train Accuracy:  0.968, Validation Accuracy:  0.972, Loss:  0.027
# Epoch   9 Batch   23/134 - Train Accuracy:  0.972, Validation Accuracy:  0.969, Loss:  0.025
# Epoch   9 Batch   24/134 - Train Accuracy:  0.967, Validation Accuracy:  0.969, Loss:  0.030
# Epoch   9 Batch   25/134 - Train Accuracy:  0.973, Validation Accuracy:  0.970, Loss:  0.025
# Epoch   9 Batch   26/134 - Train Accuracy:  0.974, Validation Accuracy:  0.972, Loss:  0.027
# Epoch   9 Batch   27/134 - Train Accuracy:  0.965, Validation Accuracy:  0.968, Loss:  0.028
# Epoch   9 Batch   28/134 - Train Accuracy:  0.969, Validation Accuracy:  0.971, Loss:  0.031
# Epoch   9 Batch   29/134 - Train Accuracy:  0.971, Validation Accuracy:  0.972, Loss:  0.022
# Epoch   9 Batch   30/134 - Train Accuracy:  0.967, Validation Accuracy:  0.973, Loss:  0.028
# Epoch   9 Batch   31/134 - Train Accuracy:  0.967, Validation Accuracy:  0.974, Loss:  0.027
# Epoch   9 Batch   32/134 - Train Accuracy:  0.973, Validation Accuracy:  0.973, Loss:  0.026
# Epoch   9 Batch   33/134 - Train Accuracy:  0.972, Validation Accuracy:  0.973, Loss:  0.031
# Epoch   9 Batch   34/134 - Train Accuracy:  0.973, Validation Accuracy:  0.971, Loss:  0.032
# Epoch   9 Batch   35/134 - Train Accuracy:  0.968, Validation Accuracy:  0.968, Loss:  0.032
# Epoch   9 Batch   36/134 - Train Accuracy:  0.966, Validation Accuracy:  0.968, Loss:  0.028
# Epoch   9 Batch   37/134 - Train Accuracy:  0.970, Validation Accuracy:  0.971, Loss:  0.029
# Epoch   9 Batch   38/134 - Train Accuracy:  0.971, Validation Accuracy:  0.972, Loss:  0.028
# Epoch   9 Batch   39/134 - Train Accuracy:  0.971, Validation Accuracy:  0.977, Loss:  0.027
# Epoch   9 Batch   40/134 - Train Accuracy:  0.972, Validation Accuracy:  0.975, Loss:  0.028
# Epoch   9 Batch   41/134 - Train Accuracy:  0.967, Validation Accuracy:  0.975, Loss:  0.029
# Epoch   9 Batch   42/134 - Train Accuracy:  0.966, Validation Accuracy:  0.977, Loss:  0.026
# Epoch   9 Batch   43/134 - Train Accuracy:  0.973, Validation Accuracy:  0.975, Loss:  0.027
# Epoch   9 Batch   44/134 - Train Accuracy:  0.970, Validation Accuracy:  0.975, Loss:  0.025
# Epoch   9 Batch   45/134 - Train Accuracy:  0.977, Validation Accuracy:  0.975, Loss:  0.023
# Epoch   9 Batch   46/134 - Train Accuracy:  0.966, Validation Accuracy:  0.975, Loss:  0.029
# Epoch   9 Batch   47/134 - Train Accuracy:  0.971, Validation Accuracy:  0.976, Loss:  0.027
# Epoch   9 Batch   48/134 - Train Accuracy:  0.967, Validation Accuracy:  0.973, Loss:  0.028
# Epoch   9 Batch   49/134 - Train Accuracy:  0.967, Validation Accuracy:  0.973, Loss:  0.027
# Epoch   9 Batch   50/134 - Train Accuracy:  0.967, Validation Accuracy:  0.973, Loss:  0.029
# Epoch   9 Batch   51/134 - Train Accuracy:  0.973, Validation Accuracy:  0.972, Loss:  0.029
# Epoch   9 Batch   52/134 - Train Accuracy:  0.968, Validation Accuracy:  0.972, Loss:  0.026
# Epoch   9 Batch   53/134 - Train Accuracy:  0.975, Validation Accuracy:  0.971, Loss:  0.028
# Epoch   9 Batch   54/134 - Train Accuracy:  0.967, Validation Accuracy:  0.971, Loss:  0.028
# Epoch   9 Batch   55/134 - Train Accuracy:  0.963, Validation Accuracy:  0.971, Loss:  0.029
# Epoch   9 Batch   56/134 - Train Accuracy:  0.965, Validation Accuracy:  0.972, Loss:  0.026
# Epoch   9 Batch   57/134 - Train Accuracy:  0.973, Validation Accuracy:  0.970, Loss:  0.026
# Epoch   9 Batch   58/134 - Train Accuracy:  0.973, Validation Accuracy:  0.972, Loss:  0.025
# Epoch   9 Batch   59/134 - Train Accuracy:  0.967, Validation Accuracy:  0.970, Loss:  0.028
# Epoch   9 Batch   60/134 - Train Accuracy:  0.970, Validation Accuracy:  0.972, Loss:  0.027
# Epoch   9 Batch   61/134 - Train Accuracy:  0.970, Validation Accuracy:  0.968, Loss:  0.024
# Epoch   9 Batch   62/134 - Train Accuracy:  0.964, Validation Accuracy:  0.964, Loss:  0.025
# Epoch   9 Batch   63/134 - Train Accuracy:  0.973, Validation Accuracy:  0.966, Loss:  0.026
# Epoch   9 Batch   64/134 - Train Accuracy:  0.963, Validation Accuracy:  0.969, Loss:  0.027
# Epoch   9 Batch   65/134 - Train Accuracy:  0.963, Validation Accuracy:  0.969, Loss:  0.028
# Epoch   9 Batch   66/134 - Train Accuracy:  0.970, Validation Accuracy:  0.971, Loss:  0.025
# Epoch   9 Batch   67/134 - Train Accuracy:  0.968, Validation Accuracy:  0.974, Loss:  0.028
# Epoch   9 Batch   68/134 - Train Accuracy:  0.970, Validation Accuracy:  0.974, Loss:  0.027
# Epoch   9 Batch   69/134 - Train Accuracy:  0.969, Validation Accuracy:  0.970, Loss:  0.027
# Epoch   9 Batch   70/134 - Train Accuracy:  0.975, Validation Accuracy:  0.972, Loss:  0.027
# Epoch   9 Batch   71/134 - Train Accuracy:  0.974, Validation Accuracy:  0.972, Loss:  0.022
# Epoch   9 Batch   72/134 - Train Accuracy:  0.972, Validation Accuracy:  0.971, Loss:  0.025
# Epoch   9 Batch   73/134 - Train Accuracy:  0.972, Validation Accuracy:  0.969, Loss:  0.028
# Epoch   9 Batch   74/134 - Train Accuracy:  0.968, Validation Accuracy:  0.967, Loss:  0.030
# Epoch   9 Batch   75/134 - Train Accuracy:  0.974, Validation Accuracy:  0.971, Loss:  0.025
# Epoch   9 Batch   76/134 - Train Accuracy:  0.972, Validation Accuracy:  0.970, Loss:  0.024
# Epoch   9 Batch   77/134 - Train Accuracy:  0.967, Validation Accuracy:  0.970, Loss:  0.026
# Epoch   9 Batch   78/134 - Train Accuracy:  0.967, Validation Accuracy:  0.972, Loss:  0.025
# Epoch   9 Batch   79/134 - Train Accuracy:  0.968, Validation Accuracy:  0.973, Loss:  0.026
# Epoch   9 Batch   80/134 - Train Accuracy:  0.976, Validation Accuracy:  0.970, Loss:  0.025
# Epoch   9 Batch   81/134 - Train Accuracy:  0.974, Validation Accuracy:  0.971, Loss:  0.025
# Epoch   9 Batch   82/134 - Train Accuracy:  0.973, Validation Accuracy:  0.971, Loss:  0.025
# Epoch   9 Batch   83/134 - Train Accuracy:  0.970, Validation Accuracy:  0.972, Loss:  0.028
# Epoch   9 Batch   84/134 - Train Accuracy:  0.966, Validation Accuracy:  0.972, Loss:  0.025
# Epoch   9 Batch   85/134 - Train Accuracy:  0.971, Validation Accuracy:  0.972, Loss:  0.027
# Epoch   9 Batch   86/134 - Train Accuracy:  0.969, Validation Accuracy:  0.970, Loss:  0.026
# Epoch   9 Batch   87/134 - Train Accuracy:  0.965, Validation Accuracy:  0.971, Loss:  0.033
# Epoch   9 Batch   88/134 - Train Accuracy:  0.977, Validation Accuracy:  0.971, Loss:  0.024
# Epoch   9 Batch   89/134 - Train Accuracy:  0.973, Validation Accuracy:  0.970, Loss:  0.025
# Epoch   9 Batch   90/134 - Train Accuracy:  0.970, Validation Accuracy:  0.971, Loss:  0.028
# Epoch   9 Batch   91/134 - Train Accuracy:  0.977, Validation Accuracy:  0.972, Loss:  0.020
# Epoch   9 Batch   92/134 - Train Accuracy:  0.977, Validation Accuracy:  0.971, Loss:  0.025
# Epoch   9 Batch   93/134 - Train Accuracy:  0.971, Validation Accuracy:  0.969, Loss:  0.025
# Epoch   9 Batch   94/134 - Train Accuracy:  0.976, Validation Accuracy:  0.972, Loss:  0.026
# Epoch   9 Batch   95/134 - Train Accuracy:  0.974, Validation Accuracy:  0.974, Loss:  0.026
# Epoch   9 Batch   96/134 - Train Accuracy:  0.971, Validation Accuracy:  0.973, Loss:  0.025
# Epoch   9 Batch   97/134 - Train Accuracy:  0.973, Validation Accuracy:  0.974, Loss:  0.025
# Epoch   9 Batch   98/134 - Train Accuracy:  0.971, Validation Accuracy:  0.975, Loss:  0.026
# Epoch   9 Batch   99/134 - Train Accuracy:  0.975, Validation Accuracy:  0.975, Loss:  0.024
# Epoch   9 Batch  100/134 - Train Accuracy:  0.973, Validation Accuracy:  0.973, Loss:  0.027
# Epoch   9 Batch  101/134 - Train Accuracy:  0.970, Validation Accuracy:  0.973, Loss:  0.027
# Epoch   9 Batch  102/134 - Train Accuracy:  0.974, Validation Accuracy:  0.972, Loss:  0.025
# Epoch   9 Batch  103/134 - Train Accuracy:  0.975, Validation Accuracy:  0.974, Loss:  0.025
# Epoch   9 Batch  104/134 - Train Accuracy:  0.974, Validation Accuracy:  0.972, Loss:  0.024
# Epoch   9 Batch  105/134 - Train Accuracy:  0.973, Validation Accuracy:  0.973, Loss:  0.030
# Epoch   9 Batch  106/134 - Train Accuracy:  0.969, Validation Accuracy:  0.972, Loss:  0.026
# Epoch   9 Batch  107/134 - Train Accuracy:  0.965, Validation Accuracy:  0.973, Loss:  0.028
# Epoch   9 Batch  108/134 - Train Accuracy:  0.969, Validation Accuracy:  0.974, Loss:  0.025
# Epoch   9 Batch  109/134 - Train Accuracy:  0.977, Validation Accuracy:  0.974, Loss:  0.024
# Epoch   9 Batch  110/134 - Train Accuracy:  0.968, Validation Accuracy:  0.974, Loss:  0.024
# Epoch   9 Batch  111/134 - Train Accuracy:  0.961, Validation Accuracy:  0.973, Loss:  0.028
# Epoch   9 Batch  112/134 - Train Accuracy:  0.971, Validation Accuracy:  0.973, Loss:  0.027
# Epoch   9 Batch  113/134 - Train Accuracy:  0.972, Validation Accuracy:  0.976, Loss:  0.027
# Epoch   9 Batch  114/134 - Train Accuracy:  0.974, Validation Accuracy:  0.976, Loss:  0.023
# Epoch   9 Batch  115/134 - Train Accuracy:  0.973, Validation Accuracy:  0.977, Loss:  0.025
# Epoch   9 Batch  116/134 - Train Accuracy:  0.975, Validation Accuracy:  0.975, Loss:  0.027
# Epoch   9 Batch  117/134 - Train Accuracy:  0.981, Validation Accuracy:  0.974, Loss:  0.022
# Epoch   9 Batch  118/134 - Train Accuracy:  0.978, Validation Accuracy:  0.973, Loss:  0.026
# Epoch   9 Batch  119/134 - Train Accuracy:  0.978, Validation Accuracy:  0.971, Loss:  0.023
# Epoch   9 Batch  120/134 - Train Accuracy:  0.971, Validation Accuracy:  0.973, Loss:  0.029
# Epoch   9 Batch  121/134 - Train Accuracy:  0.966, Validation Accuracy:  0.972, Loss:  0.024
# Epoch   9 Batch  122/134 - Train Accuracy:  0.967, Validation Accuracy:  0.970, Loss:  0.026
# Epoch   9 Batch  123/134 - Train Accuracy:  0.976, Validation Accuracy:  0.973, Loss:  0.024
# Epoch   9 Batch  124/134 - Train Accuracy:  0.971, Validation Accuracy:  0.972, Loss:  0.024
# Epoch   9 Batch  125/134 - Train Accuracy:  0.977, Validation Accuracy:  0.972, Loss:  0.022
# Epoch   9 Batch  126/134 - Train Accuracy:  0.971, Validation Accuracy:  0.971, Loss:  0.026
# Epoch   9 Batch  127/134 - Train Accuracy:  0.968, Validation Accuracy:  0.973, Loss:  0.024
# Epoch   9 Batch  128/134 - Train Accuracy:  0.970, Validation Accuracy:  0.971, Loss:  0.028
# Epoch   9 Batch  129/134 - Train Accuracy:  0.968, Validation Accuracy:  0.971, Loss:  0.025
# Epoch   9 Batch  130/134 - Train Accuracy:  0.973, Validation Accuracy:  0.970, Loss:  0.023
# Epoch   9 Batch  131/134 - Train Accuracy:  0.967, Validation Accuracy:  0.973, Loss:  0.027
# Epoch   9 Batch  132/134 - Train Accuracy:  0.968, Validation Accuracy:  0.974, Loss:  0.023
# save_path checkpoints/dev
# Model Trained and Saved

# %% [markdown]
# ### 保存参数
#
# 保存 `batch_size` 和 `save_path` 参数以进行推论（for inference）。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # 检查点

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## 句子到序列
#
# 要向模型提供要翻译的句子，你首先需要预处理该句子。实现函数 `sentence_to_seq()` 以预处理新的句子。
#
# - 将句子转换为小写形式
# - 使用 `vocab_to_int` 将单词转换为 id
#  - 如果单词不在词汇表中，将其转换为`<UNK>` 单词 id

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    debugprint('sentence',sentence,'\nvocab_to_int',vocab_to_int)
    ll = [vocab_to_int[word] if vocab_to_int.__contains__(word) else vocab_to_int['<UNK>'] for word in sentence.split()]
    return ll


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## 翻译
#
# 将 `translate_sentence` 从英语翻译成法语。

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [99, 226, 203, 181, 103, 20, 118]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [236, 214, 185, 180, 253, 110, 300, 309, 1]
#   French Words: ['il', 'est', 'un', 'vieux', "d'", 'les', 'poires', '.', '<EOS>']

# %% [markdown]
# ## 不完美的翻译
#
# 你可能注意到了，某些句子的翻译质量比其他的要好。因为你使用的数据集只有 227 个英语单词，但实际生活中有数千个单词，只有使用这些单词的句子结果才会比较理想。对于此项目，不需要达到完美的翻译。但是，如果你想创建更好的翻译模型，则需要更好的数据。
#
# 你可以使用 [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar) 语料库训练模型。该数据集拥有更多的词汇，讨论的话题也更丰富。但是，训练时间要好多天的时间，所以确保你有 GPU 并且对于我们提供的数据集，你的神经网络性能很棒。提交此项目后，别忘了研究下 WMT10 语料库。
#
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。保存记事本文件为 “dlnd_language_translation.ipynb”，再通过菜单中的“文件” ->“下载为”将其另存为 HTML 格式。提交的项目文档中需包含“helper.py”和“problem_unittests.py”文件。
